# %%
# %pip install torch torchvision --index-url https://download.pytorch.org/whl/cu128
# Out:
# Looking in indexes: https://download.pytorch.org/whl/cu128
# Requirement already satisfied: torch in e:\m-github-pytorch\mastering-pytorch-2nd\.venv\lib\site-packages (2.8.0)
# Requirement already satisfied: torchvision in e:\m-github-pytorch\mastering-pytorch-2nd\.venv\lib\site-packages (0.23.0)
# Requirement already satisfied: filelock in e:\m-github-pytorch\mastering-pytorch-2nd\.venv\lib\site-packages (from torch) (3.13.1)
# Requirement already satisfied: typing-extensions>=4.10.0 in e:\m-github-pytorch\mastering-pytorch-2nd\.venv\lib\site-packages (from torch) (4.12.2)
# Requirement already satisfied: sympy>=1.13.3 in e:\m-github-pytorch\mastering-pytorch-2nd\.venv\lib\site-packages (from torch) (1.13.3)
# Requirement already satisfied: networkx in e:\m-github-pytorch\mastering-pytorch-2nd\.venv\lib\site-packages (from torch) (3.3)
# Requirement already satisfied: jinja2 in e:\m-github-pytorch\mastering-pytorch-2nd\.venv\lib\site-packages (from torch) (3.1.4)
# Requirement already satisfied: fsspec in e:\m-github-pytorch\mastering-pytorch-2nd\.venv\lib\site-packages (from torch) (2024.6.1)
# Requirement already satisfied: setuptools in e:\m-github-pytorch\mastering-pytorch-2nd\.venv\lib\site-packages (from torch) (70.2.0)
# Requirement already satisfied: numpy in e:\m-github-pytorch\mastering-pytorch-2nd\.venv\lib\site-packages (from torchvision) (2.1.2)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in e:\m-github-pytorch\mastering-pytorch-2nd\.venv\lib\site-packages (from torchvision) (11.0.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in e:\m-github-pytorch\mastering-pytorch-2nd\.venv\lib\site-packages (from sympy>=1.13.3->torch) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in e:\m-github-pytorch\mastering-pytorch-2nd\.venv\lib\site-packages (from jinja2->torch) (2.1.5)
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# - 파이토치 버전과 관련 정보를 출력하는 코드

# %%
import torch
import torchvision

print("PyTorch version:", torch.__version__)
print("Torchvision version:", torchvision.__version__)
print("CUDA available:", torch.cuda.is_available())
if torch.cuda.is_available():
    print("CUDA device count:", torch.cuda.device_count())
    print("Current CUDA device:", torch.cuda.current_device())
    print("CUDA device name:", torch.cuda.get_device_name(torch.cuda.current_device()))
else:
    print("CUDA device is not available.")
# Out:
# PyTorch version: 2.8.0+cpu
# Torchvision version: 0.23.0+cpu
# CUDA available: False
# CUDA device is not available.
