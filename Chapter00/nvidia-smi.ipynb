# %% [markdown]
# 1. 파이썬 코드 동작 확인합니다

# %%
print('nvidia-smi 명령어를 실행합니다')
# Out:
# nvidia-smi 명령어를 실행합니다

# %% [markdown]
# 2. nvidia-smi는 NVIDIA GPU의 상태, 드라이버 버전, CUDA 버전 등을 보여주는 명령어입니다.
# - !는 Jupyter 셀 안에서 터미널 명령어를 실행할 때 사용하는 접두어입니다

# %%
# !nvidia-smi
# Out:
# Wed Sep 10 18:52:10 2025
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 581.15                 Driver Version: 581.15         CUDA Version: 13.0     |
# +-----------------------------------------+------------------------+----------------------+
# | GPU  Name                  Driver-Model | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  NVIDIA GeForce RTX 3060      WDDM  |   00000000:01:00.0  On |                  N/A |
# |  0%   44C    P5             29W /  170W |    1631MiB /  12288MiB |     22%      Default |
# |                                         |                        |                  N/A |
# +-----------------------------------------+------------------------+----------------------+
#
# +-----------------------------------------------------------------------------------------+
# | Processes:                                                                              |
# |  GPU   GI   CI              PID   Type   Process name                        GPU Memory |
# |        ID   ID                                                               Usage      |
# |=========================================================================================|
# |    0   N/A  N/A            4440    C+G   ....0.3485.54\msedgewebview2.exe      N/A      |
# |    0   N/A  N/A            6564    C+G   ...Chrome\Application\chrome.exe      N/A      |
# |    0   N/A  N/A            9020    C+G   ...5n1h2txyewy\TextInputHost.exe      N/A      |
# |    0   N/A  N/A            9960    C+G   ...Chrome\Application\chrome.exe      N/A      |
# |    0   N/A  N/A           10536    C+G   ...8bbwe\PhoneExperienceHost.exe      N/A      |
# |    0   N/A  N/A           10780    C+G   ...ntrolPanel\SystemSettings.exe      N/A      |
# |    0   N/A  N/A           11416    C+G   ...m\113.0.1.0\GoogleDriveFS.exe      N/A      |
# |    0   N/A  N/A           11556    C+G   ...xyewy\ShellExperienceHost.exe      N/A      |
# |    0   N/A  N/A           11992    C+G   ...ms\Microsoft VS Code\Code.exe      N/A      |
# |    0   N/A  N/A           12888    C+G   ...em32\ApplicationFrameHost.exe      N/A      |
# |    0   N/A  N/A           13424    C+G   ....0.3485.54\msedgewebview2.exe      N/A      |
# |    0   N/A  N/A           14764    C+G   ...crosoft\OneDrive\OneDrive.exe      N/A      |
# |    0   N/A  N/A           16984    C+G   ...2txyewy\CrossDeviceResume.exe      N/A      |
# |    0   N/A  N/A           17992    C+G   ...indows\System32\ShellHost.exe      N/A      |
# |    0   N/A  N/A           18832    C+G   C:\Windows\explorer.exe               N/A      |
# |    0   N/A  N/A           18848    C+G   ..._cw5n1h2txyewy\SearchHost.exe      N/A      |
# |    0   N/A  N/A           20084    C+G   ....0.3485.54\msedgewebview2.exe      N/A      |
# |    0   N/A  N/A           21152    C+G   ...y\StartMenuExperienceHost.exe      N/A      |
# +-----------------------------------------------------------------------------------------+
